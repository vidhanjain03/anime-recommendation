# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import tqdm as tqdm
import tensorflow as tf
import nltk
import re
import random
import unicodedata
import string

# %%
#read the csv files
anime = pd.read_csv('/content/drive/MyDrive/anime_recommendation/archive/anime.csv')
rating = pd.read_csv('/content/drive/MyDrive/anime_recommendation/archive/rating.csv')

# %%
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')
def clean_text(text):
    text = unicode_to_ascii(text.lower().strip())
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"\r", "", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "that is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"how's", "how is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"n'", "ng", text)
    text = re.sub(r"'bout", "about", text)
    text = re.sub(r"'til", "until", text)
    text = re.sub(r"[-()\"#/@;:<>{}`+=~|.!?,]", "", text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub("(\\W)"," ",text)
    text = re.sub('\S*\d\S*\s*','', text)
    #text =  "<sos> " +  text + " <eos>"
    return text

# %%
anime.dropna(inplace=True)

# %%
for i in range(len(anime)):
    anime['genre'].iloc[i] = clean_text(anime['genre'].iloc[i])
# Out:
# <ipython-input-6-a88071768d57>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime['genre'].iloc[i] = clean_text(anime['genre'].iloc[i])

# %% [markdown]
# Our recommendation system actually provides recommendations based on users' anime watching habits and ratings.
#
# So, we suggest
# 1. Movies that are liked by other users who have similar tastes
# 2. Movies having similar genre
#
# If our user hasn't watched these anime series before, we definitely recommend them.
#
# This data set contains information on user preference data from 73,516 users on 12,294 anime. Each user is able to add anime to their completed list and give it a rating and this data set is a compilation of those ratings.

# %%
# Finding the correlation between the movie genres
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
anime_tv = anime[anime['type'] == 'TV']
cv = CountVectorizer(ngram_range=(1,1))
tfidf_matrix = cv.fit_transform(anime_tv['genre']).toarray()

# %%
X_train = pd.DataFrame(tfidf_matrix)
similarity = sklearn.metrics.pairwise.cosine_similarity(X_train, Y=None, dense_output=True)

# %%
sim_df = pd.DataFrame(similarity)
genre_corr = pd.DataFrame(sim_df.unstack().sort_values(ascending=False), columns=["corr"])
genre_corr.index.names = ["animeid_1", "animeid_2"]
genre_corr = genre_corr[genre_corr['corr']>0.55]

# %%
genre_corr.shape
# Out:
# (1067312, 1)

# %%
genre_corr.tail(10)
# Out:
#                          corr
# animeid_1 animeid_2
# 2381      682        0.555556
# 783       2248       0.555556
# 2941      116        0.555556
# 2381      710        0.555556
# 116       132        0.555556
# 2941      1256       0.555556
#           1261       0.555556
# 1292      3207       0.555556
# 303       395        0.555556
# 343       116        0.555556

# %%
anime_tv.iloc[343]
# Out:
# anime_id                                                 6033
# name                                          Dragon Ball Kai
# genre       action adventure comedy fantasy martial arts s...
# type                                                       TV
# episodes                                                   97
# rating                                                   7.95
# members                                                116832
# Name: 588, dtype: object

# %%
anime_tv.iloc[116]
# Out:
# anime_id                                                 6811
# name                                   InuYasha: Kanketsu-hen
# genre       action adventure comedy demons fantasy magic r...
# type                                                       TV
# episodes                                                   26
# rating                                                   8.37
# members                                                 99128
# Name: 173, dtype: object

# %%
anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0                  drama romance school supernatural  Movie        1    9.37
# 1  action adventure drama fantasy magic military ...     TV       64    9.26
# 2  action comedy historical parody samurai scifi ...     TV       51    9.25
# 3                                     scifi thriller     TV       24    9.17
# 4  action comedy historical parody samurai scifi ...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
rating.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %% [markdown]
# Some users have watched some anime shows but did not rate it. These show up as -1 in the dataset and we are taking them off because we do not want to recommend an anime that user already watched

# %%
watched_but_not_rated = rating.loc[rating["rating"] < 0,("user_id","anime_id")]
rating = rating[rating["rating"] >= 0]
rating.columns = ['user_id', 'anime_id', 'user_rating']

# %%
df = anime.merge(rating, how="left", on="anime_id")
df.dropna(inplace=True)

# %% [markdown]
# ### Lets say we want to make predictions for TV type animes

# %%
df = df[df["type"]=="TV"]

# %%
df.head(10)
# Out:
#       anime_id                              name  \
# 1961      5114  Fullmetal Alchemist: Brotherhood
# 1962      5114  Fullmetal Alchemist: Brotherhood
# 1963      5114  Fullmetal Alchemist: Brotherhood
# 1964      5114  Fullmetal Alchemist: Brotherhood
# 1965      5114  Fullmetal Alchemist: Brotherhood
# 1966      5114  Fullmetal Alchemist: Brotherhood
# 1967      5114  Fullmetal Alchemist: Brotherhood
# 1968      5114  Fullmetal Alchemist: Brotherhood
# 1969      5114  Fullmetal Alchemist: Brotherhood
# 1970      5114  Fullmetal Alchemist: Brotherhood
#
#                                                   genre type episodes  rating  \
# 1961  action adventure drama fantasy magic military ...   TV       64    9.26
# 1962  action adventure drama fantasy magic military ...   TV       64    9.26
# 1963  action adventure drama fantasy magic military ...   TV       64    9.26
# 1964  action adventure drama fantasy magic military ...   TV       64    9.26
# 1965  action adventure drama fantasy magic military ...   TV       64    9.26
# 1966  action adventure drama fantasy magic military ...   TV       64    9.26
# 1967  action adventure drama fantasy magic military ...   TV       64    9.26
# 1968  action adventure drama fantasy magic military ...   TV       64    9.26
# 1969  action adventure drama fantasy magic military ...   TV       64    9.26
# 1970  action adventure drama fantasy magic military ...   TV       64    9.26
#
#       members  user_id  user_rating
# 1961   793665      3.0         10.0
# 1962   793665     10.0         10.0
# 1963   793665     11.0          8.0
# 1964   793665     12.0          9.0
# 1965   793665     17.0         10.0
# 1966   793665     19.0          9.0
# 1967   793665     21.0          9.0
# 1968   793665     30.0         10.0
# 1969   793665     38.0         10.0
# 1970   793665     39.0         10.0

# %%
#Drop Anime movies have least votes
anime_watched_count = pd.DataFrame(df.anime_id.value_counts())
anime_watched_count.columns = ["total_vote"]   # it was ['anime_id']
anime_watched_count = anime_watched_count[anime_watched_count["total_vote"] > 250]

# %%
anime_watched_count
# Out:
#        total_vote
# 1535        34226
# 11757       26310
# 16498       25290
# 1575        24126
# 6547        23565
# ...           ...
# 971           255
# 342           255
# 2041          254
# 21267         254
# 3363          252
#
# [1575 rows x 1 columns]

# %%
common_anime = anime_watched_count.index
df = df[df["anime_id"].isin(common_anime)]
df.head()
# Out:
#       anime_id                              name  \
# 1961      5114  Fullmetal Alchemist: Brotherhood
# 1962      5114  Fullmetal Alchemist: Brotherhood
# 1963      5114  Fullmetal Alchemist: Brotherhood
# 1964      5114  Fullmetal Alchemist: Brotherhood
# 1965      5114  Fullmetal Alchemist: Brotherhood
#
#                                                   genre type episodes  rating  \
# 1961  action adventure drama fantasy magic military ...   TV       64    9.26
# 1962  action adventure drama fantasy magic military ...   TV       64    9.26
# 1963  action adventure drama fantasy magic military ...   TV       64    9.26
# 1964  action adventure drama fantasy magic military ...   TV       64    9.26
# 1965  action adventure drama fantasy magic military ...   TV       64    9.26
#
#       members  user_id  user_rating
# 1961   793665      3.0         10.0
# 1962   793665     10.0         10.0
# 1963   793665     11.0          8.0
# 1964   793665     12.0          9.0
# 1965   793665     17.0         10.0

# %%
user_movie = df.pivot_table(index="user_id", columns="anime_id", values="user_rating")
user_movie.head()
# Out:
# anime_id  1      6      7      8      15     16     17     18     19     \
# user_id
# 1.0         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2.0         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3.0         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5.0         NaN    8.0    NaN    NaN    6.0    NaN    6.0    6.0    NaN
# 7.0         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# anime_id  20     ...  32681  32696  32729  32828  32935  32947  32998  33028  \
# user_id          ...
# 1.0         NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2.0         NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3.0         8.0  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5.0         6.0  ...    NaN    NaN    NaN    7.0    NaN    NaN    NaN    NaN
# 7.0         NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# anime_id  33222  33421
# user_id
# 1.0         NaN    NaN
# 2.0         NaN    NaN
# 3.0         NaN    NaN
# 5.0         NaN    NaN
# 7.0         NaN    NaN
#
# [5 rows x 1575 columns]

# %% [markdown]
# #### Lets take a random user from user_movie table in order to make recommendations to that person

# %%
rnd_user = int(pd.Series(user_movie.index).sample(1, random_state=28))
rnd_user_df = user_movie[user_movie.index == rnd_user]
rnd_user
# Out:
# 47697

# %%
#The number of movies watched by user 47697
animes_watched = rnd_user_df.columns[~rnd_user_df.isnull().any()].tolist()
len(animes_watched)
# Out:
# 70

# %%
#Lets take random movie from movies watched by user 47697
rnd_anime = int(pd.Series(rnd_user_df.columns[~rnd_user_df.isnull().any()]).sample(1, random_state=42).values)
rnd_anime
# Out:
# 341

# %% [markdown]
# #### Lets predict anime of similar genre as 341

# %%
genre_corr.loc[341]
# Out:
#                corr
# animeid_2
# 341        1.000000
# 376        1.000000
# 236        1.000000
# 309        1.000000
# 895        0.894427
# ...             ...
# 464        0.566947
# 379        0.566947
# 355        0.566947
# 767        0.566947
# 674        0.566947
#
# [269 rows x 1 columns]

# %%
anime_tv.iloc[341]
# Out:
# anime_id                             1472
# name                        City Hunter 3
# genre       action comedy mystery shounen
# type                                   TV
# episodes                               13
# rating                               7.95
# members                              6723
# Name: 584, dtype: object

# %%
anime_tv.iloc[236]
# Out:
# anime_id                             1471
# name                        City Hunter 2
# genre       action comedy mystery shounen
# type                                   TV
# episodes                               63
# rating                               8.12
# members                              8199
# Name: 390, dtype: object

# %% [markdown]
# #### Now, lets predict based on other users who have same taste as you

# %%
animes_watched_df = user_movie[animes_watched]
animes_watched_df.iloc[0:5,0:5]
# Out:
# anime_id   45  50  52  60  66
# user_id
# 1.0       NaN NaN NaN NaN NaN
# 2.0       NaN NaN NaN NaN NaN
# 3.0       NaN NaN NaN NaN NaN
# 5.0       7.0 NaN NaN NaN NaN
# 7.0       NaN NaN NaN NaN NaN

# %%
user_watched_count = animes_watched_df.T.notnull().sum()
user_watched_count = user_watched_count.reset_index()
user_watched_count.columns = ["user_id", "count"]
user_watched_count.head()
# Out:
#    user_id  count
# 0      1.0      0
# 1      2.0      0
# 2      3.0      4
# 3      5.0     20
# 4      7.0     14

# %%
same_anime = user_watched_count[user_watched_count["count"] > len(animes_watched)/2.5].\
    sort_values(by="count", ascending=False)

len(same_anime)
# Out:
# 1344

# %%
same_anime.head()
# Out:
#        user_id  count
# 44643  47697.0     70
# 23406  24988.0     66
# 10699  11398.0     61
# 42730  45659.0     61
# 39886  42635.0     61

# %%
final_df = pd.concat([animes_watched_df[animes_watched_df.index.isin(same_anime["user_id"].values)],
                      rnd_user_df[animes_watched]])

# %%
final_df
# Out:
# anime_id  45     50     52     60     66     72     76     77     101    \
# user_id
# 226.0       8.0    8.0    NaN    7.0    NaN    7.0    NaN    NaN    8.0
# 248.0       9.0    7.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 294.0       7.0    8.0    NaN    NaN    NaN    7.0    NaN    NaN    6.0
# 317.0       NaN    NaN    NaN    9.0    7.0    NaN    8.0    8.0    NaN
# 478.0       NaN    NaN    9.0    NaN    NaN    NaN    9.0    9.0    9.0
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 73356.0     7.0    7.0    7.0    9.0    NaN    7.0    8.0    8.0    7.0
# 73378.0     9.0    8.0    NaN    NaN    NaN    9.0    NaN    NaN    9.0
# 73417.0     7.0    NaN    NaN    6.0    NaN    8.0    NaN    NaN    7.0
# 73499.0    10.0    8.0    NaN    NaN    NaN    NaN    NaN    NaN    9.0
# 47697.0    10.0    8.0    9.0   10.0   10.0   10.0   10.0    7.0   10.0
#
# anime_id  120    ...  6045   6547   7054   7674   9989   10800  14397  14713  \
# user_id          ...
# 226.0       NaN  ...    7.0    9.0    7.0    NaN    NaN    NaN    NaN    9.0
# 248.0       NaN  ...   10.0    8.0    9.0    9.0    8.0    9.0    9.0    NaN
# 294.0       8.0  ...    9.0    9.0   10.0    9.0    9.0    9.0    9.0    7.0
# 317.0       8.0  ...    NaN    8.0    9.0    7.0    7.0    NaN    NaN    NaN
# 478.0       NaN  ...   10.0   10.0    NaN    9.0   10.0   10.0   10.0    8.0
# ...         ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 73356.0     7.0  ...   10.0    NaN    9.0    NaN    NaN    7.0    NaN    6.0
# 73378.0     NaN  ...    8.0    8.0    8.0    9.0   10.0    9.0    9.0    NaN
# 73417.0     7.0  ...    8.0    9.0    9.0    NaN    7.0    8.0    7.0    7.0
# 73499.0     NaN  ...    9.0    9.0    9.0    9.0   10.0    9.0    9.0    NaN
# 47697.0     7.0  ...   10.0   10.0   10.0    8.0   10.0   10.0   10.0    8.0
#
# anime_id  20971  23289
# user_id
# 226.0       NaN   10.0
# 248.0       NaN    NaN
# 294.0       NaN    8.0
# 317.0       NaN    7.0
# 478.0       NaN   10.0
# ...         ...    ...
# 73356.0     NaN    NaN
# 73378.0     NaN    9.0
# 73417.0     NaN    7.0
# 73499.0     NaN    7.0
# 47697.0     8.0    9.0
#
# [1345 rows x 70 columns]

# %%
corrdf = pd.DataFrame(final_df.T.corr().unstack().sort_values().drop_duplicates(), columns=["corr"])
corrdf.head()
# Out:
#                      corr
# user_id user_id
# 14959.0 55382.0 -1.000000
# 7446.0  58874.0 -0.945343
# 10761.0 55094.0 -0.935971
# 28597.0 41889.0 -0.925900
# 59966.0 67489.0 -0.918947

# %%
corrdf.index.names = ["user_1", "user_2"]
corrdf.reset_index(inplace=True)
corrdf.head()
# Out:
#     user_1   user_2      corr
# 0  14959.0  55382.0 -1.000000
# 1   7446.0  58874.0 -0.945343
# 2  10761.0  55094.0 -0.935971
# 3  28597.0  41889.0 -0.925900
# 4  59966.0  67489.0 -0.918947

# %%
corrdf = corrdf[(corrdf["user_1"] == rnd_user) & (corrdf["corr"] > 0.55)]
corrdf = corrdf.sort_values(by="corr", ascending=False)
corrdf = corrdf.drop(columns="user_1").rename(columns={"user_2": "user_id"})
corrdf.head()
# Out:
#         user_id      corr
# 859963  61389.0  0.661313
# 843738  44322.0  0.601413
# 842347  67006.0  0.597483
# 831291  25693.0  0.569970

# %%
top_user = corrdf.merge(rating[["user_id", "anime_id", "user_rating"]], how='inner')
top_user = top_user[top_user["user_id"] != rnd_user]
top_user["user_id"].nunique()
# Out:
# 4

# %%
top_user
# Out:
#       user_id      corr  anime_id  user_rating
# 0     61389.0  0.661313         1            9
# 1     61389.0  0.661313         5            8
# 2     61389.0  0.661313        15            7
# 3     61389.0  0.661313        30            8
# 4     61389.0  0.661313        31            8
# ...       ...       ...       ...          ...
# 2033  25693.0  0.569970     24075           10
# 2034  25693.0  0.569970     24135           10
# 2035  25693.0  0.569970     24455           10
# 2036  25693.0  0.569970     25159           10
# 2037  25693.0  0.569970     26019           10
#
# [2038 rows x 4 columns]

# %%
top_user["wr"] = top_user["corr"] * top_user["user_rating"]
recommend = top_user.sort_values(by="wr", ascending=False)["anime_id"]

# %%
#if user have alredy watched but havent give rate drop them
wched_l = watched_but_not_rated[watched_but_not_rated['user_id'] == rnd_user]["anime_id"].tolist()
out = [x for x in recommend.tolist() if x not in wched_l]

# %%
# Giving Output As Anime Names
def anime_id_to_name(ıd):
    qut = pd.DataFrame(anime[anime["anime_id"].isin(ıd)]["name"])
    return qut

Recommendations = anime_id_to_name(out)
Recommendations[:10]
# Out:
#                                                  name
# 1                    Fullmetal Alchemist: Brotherhood
# 3                                         Steins;Gate
# 4                                       Gintama&#039;
# 6                              Hunter x Hunter (2011)
# 8   Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 9                            Gintama&#039;: Enchousen
# 10                               Clannad: After Story
# 12                                            Gintama
# 13                 Code Geass: Hangyaku no Lelouch R2
# 15                      Sen to Chihiro no Kamikakushi
